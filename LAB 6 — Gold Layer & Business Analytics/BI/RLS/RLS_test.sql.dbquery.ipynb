-- %%
-- Since I think group updates take some time, I created this primitive script to check if the filtering function works. (it does :D)

-- CREATE OR REPLACE FUNCTION IDENTIFIER(:catalog_name).IDENTIFIER(:schema_name).author_row_filter(author_name STRING)
-- RETURN 
--     (current_user() = 'my_email' AND author_name = 'Metallica');


-- SELECT author, title 
-- FROM dbr_dev.music_analytics.v_dim_music_metadata;
