# %%
bronze_name = "dbr_dev.music_analytics.bronze_music_stats"
silver_name = "dbr_dev.music_analytics.bronze_music_stats"

# %%
bronze_df = spark.read.table(bronze_name)

# %%
bronze_df.count()

# %%
silver_df.count()
